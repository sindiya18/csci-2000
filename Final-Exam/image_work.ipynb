# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
#img = mpimg open('home/sindiya/csci-2000-personal/Final-Exam/peppers.png')
img = mpimg.imread('peppers.png') #'rgb_peppers.png'
imgplot = plt.imshow(img)
print('The dimension of the image is',img.shape)

plt.imshow(img, cmap='gray')
plt.colorbar()
# Out:
# The dimension of the image is (384, 512, 3)

# %%
def rgb2gray(rgb):
    np.average(pixel)
    return np.dot(rgb [0.299, 0.587, 0.144])

img = mpimg.imread('peppers.png')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap = plt.get_cmap('grayscale'))
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-361dbe19d2f3> in <module>()
#       5
#       6 img = mpimg.imread('peppers.png')
# ----> 7 gray = rgb2gray(img)
#       8 plt.imshow(gray, cmap = plt.get_cmap('grayscale'))
#       9 plt.show
#
# <ipython-input-4-361dbe19d2f3> in rgb2gray(rgb)
#       1
#       2 def rgb2gray(rgb):
# ----> 3     np.average(pixel)
#       4     return np.dot(rgb [0.299, 0.587, 0.144])
#       5
#
# NameError: name 'pixel' is not defined
