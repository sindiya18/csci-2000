# %%
#Sindiya Mohan
#100600998

#Plot inline
# %pylab inline:

#Imports 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from JSAnimation.IPython_display import display_animation

import urllib
from mpl_toolkits.basemap import Basemap

#importing csvalues
import csv
Category = []
Lat = []
Long = []
Cases = []

#plot map.
plt.figure(figsize=(10, 10))

# to create the earth plot
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

#Open csv file and gather the required data and append
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

#Convert the strings into float
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

k = 0

#find Measles for the Measles plot.
for i in range (k, len(Category)):
    if (Category[k] == 'Measles'):
        x, y = earth(Long[k], Lat[k])
        
        # if statements for markersize due to amount of cases
        if (Cases[k] >= 0 and Cases[k] < 5000):
            earth.plot(x, y, 'meas',markersize=5,alpha=.5)
            
        elif (Cases[k] >= 5000 and Cases[k] < 10000):
            earth.plot(x, y, 'meas',markersize=10,alpha=.5)
            
        elif (Cases[k] >= 10000 and Cases[k] < 15000):
            earth.plot(x, y, 'meas',markersize=15,alpha=.5)
            
        elif (Cases[k] >= 15000 and Cases[k] < 20000):
            earth.plot(x, y, 'meas',markersize=20,alpha=.5)
            
        elif (Cases[k] >= 20000 and Cases[k] < 25000):
            earth.plot(x, y, 'meas',markersize=25,alpha=.5)
            
        elif (Cases[k] >= 25000 and Cases[k] < 30000):
            earth.plot(x, y, 'meas',markersize=30,alpha=.5)
            
        elif (Cases[k] >= 30000 and Cases[k] < 35000):
            earth.plot(x, y, 'meas',markersize=35,alpha=.5)
            
        elif (Cases[k] >= 35000 and Cases[k] < 40000):
            earth.plot(x, y, 'meas',markersize=40,alpha=.5)
            
        elif (Cases[k] >= 40000 and Cases[k] < 45000):
            earth.plot(x, y, 'meas',markersize=45,alpha=.5)
            
        elif (Cases[k] >= 45000 and Cases[k] < 50000):
            earth.plot(x, y, 'meas',markersize=50,alpha=.5)
            
        elif (Cases[k] >= 50000 and Cases[k] < 55000):
            earth.plot(x, y, 'meas',markersize=55,alpha=.5)
            
        elif (Cases[k] >= 55000 and Cases[k] < 60000):
            earth.plot(x, y, 'meas',markersize=60,alpha=.5)
            
        elif (Cases[k] >= 60000 and Cases[k] < 65000):
            earth.plot(x, y, 'meas',markersize=65,alpha=.5)
            
        elif (Cases[k] >= 65000 and Cases[k] < 70000):
            earth.plot(x, y, 'meas',markersize=70,alpha=.5)
            
        elif (Cases[k] >= 70000 and Cases[k] < 75000):
            earth.plot(x, y, 'meas',markersize=75,alpha=.5)
            
        elif (Cases[k] >= 75000 and Cases[k] < 80000):
            earth.plot(x, y, 'meas',markersize=80,alpha=.5)
            
        elif (Cases[k] >= 80000 and Cases[k] < 85000):
            earth.plot(x, y, 'meas',markersize=85,alpha=.5)
            
        elif (Cases[k] >= 85000 and Cases[k] < 90000):
            earth.plot(x, y, 'meas',markersize=90,alpha=.5)
            
        elif (Cases[k] >= 90000 and Cases[k] < 95000):
            earth.plot(x, y, 'meas',markersize=95,alpha=.5)
            
        elif (Cases[k] >= 95000 and Cases[k] < 100000):
            earth.plot(x, y, 'meas',markersize=100,alpha=.5)
            
        elif (Cases[k] >= 100000 and Cases[k] < 105000):
            earth.plot(x, y, 'meas',markersize=105,alpha=.5)
            
        elif (Cases[k] >= 105000 and Cases[k] < 110000):
            earth.plot(x, y, 'meas',markersize=110,alpha=.5)
            
        elif (Cases[k] >= 110000 and Cases[k] < 115000):
            earth.plot(x, y, 'meas',markersize=115,alpha=.5)
            
        elif (Cases[k] >= 115000 and Cases[k] < 120000):
            earth.plot(x, y, 'meas',markersize=120,alpha=.5)
            
        elif (Cases[k] >= 120000 and Cases[k] < 125000):
            earth.plot(x, y, 'meas',markersize=125,alpha=.5)
            
        elif (Cases[k] >= 125000 and Cases[k] < 130000):
            earth.plot(x, y, 'meas',markersize=130,alpha=.5)
            
        elif (Cases[k] >= 130000 and Cases[k] < 135000):
            earth.plot(x, y, 'meas',markersize=135,alpha=.5)
            
        elif (Cases[k] >= 135000 and Cases[k] < 140000):
            earth.plot(x, y, 'meas',markersize=140,alpha=.5)
    k += 1
    
plt.title("Measles outbreaks (100600998)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9849bb363a03> in <module>()
#       3
#       4 #Plot inline
# ----> 5 get_ipython().magic('pylab inline:')
#       6
#       7 #Imports
#
# /home/sindiya/anaconda3/lib/python3.4/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /home/sindiya/anaconda3/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# ...
